# %% [markdown]
# # Projeto final em ciência de dados
#
# Baseado no método CRISP-DM.
#
# ---
#
# ## Objetivo
#
# - Identificar um problema que pode ser resolvido usando ciência de dados:
#     - Análise descritiva usando ciência de dados;
#     - Análise preditiva;
#     - Análise prescritiva.
# - Problema real: pode ser na empresa em que vocês trabalham ou um problema social (com dados públicos, por exemplo).
# - Para agora: definir o problema e buscar os dados e autorização, caso necessário.
#
# ## Estrutura do projeto
#
# 1. Descrição da empresa e do problema;
# 2. Identificação dos dados necessários para entender e solucionar o problema, tanto dados internos quanto externos;
# 3. Propor uma Arquitetura de Dados, especificando as fontes de dados e tecnologias para extração dos dados;
# 4. Extrair e consolidar dados;
# 5. Realizar pelo menos uma análise (supervisionada ou não supervisionada);
# 6. Indicar as respectivas ações possíveis;
# 7. Projeto de implantação da solução no processo de negócio equivalente.
#
# ---
#
# ## Resumo do projeto
#
# Este projeto utiliza dados públicos da Receita Federal do Brasil, referentes à distribuição de renda entre contribuintes do Imposto de Renda da Pessoa Física. O objetivo é compreender e visualizar a desigualdade de renda no Brasil e suas variações entre estados e anos, buscando apoiar diagnósticos e políticas públicas com base em evidências.
#
# ## Desenvolvido por
#
# - Bruno Silveira da Silva
# - Christian Aguiar Plentz
# - Gabriel de Freitas Adolfo
#
# ---

# %% [markdown]
# ## 1. Empresa e problema
#
# ### 1.1 Empresa
#
# A Receita Federal do Brasil (RFB) é um órgão vinculado ao Ministério da Fazenda, responsável pela administração dos tributos federais e pelo controle aduaneiro. Seu papel é essencial para a arrecadação de receitas da União, o combate à sonegação fiscal, à evasão de divisas e à lavagem de dinheiro.
#
# A RFB é uma das maiores instituições públicas do país, com abrangência nacional e uma base de dados extremamente ampla sobre contribuintes pessoas físicas e jurídicas.
#
# Os “clientes” da Receita Federal são, de forma ampla, todos os cidadãos e empresas brasileiras que contribuem com tributos federais.
#
# ### 1.2 Problema
#
# Apesar do aumento do acesso a dados econômicos no Brasil, a compreensão da desigualdade de renda entre regiões e ao longo do tempo ainda é limitada.
#
# Mesmo com políticas públicas voltadas à redistribuição de renda (como o Bolsa Família, reajustes do salário mínimo e programas de crédito), a concentração de renda permanece elevada e varia significativamente entre os estados brasileiros.
#
# **Problema central:** "Como os estados brasileiros se agrupam em relação aos perfis de renda dos contribuintes e características associadas (bens, despesas e impostos)?"
#
# ### 1.3 Como os dados podem ajudar a resolver o problema
#
# A base de Distribuição de Renda da Receita Federal contém informações agregadas por centis da população declarantes (do 1º ao 100º centil), com indicadores como:
# - Renda média;
# - Renda total declarada;
# - Quantidade de declarantes;
# - Unidade da federação;
# - Ano-base da declaração.
#
# > Um centil é uma divisão de uma distribuição de dados em 100 partes iguais. Ou seja: se você ordenar todas as rendas das pessoas do menor para o maior valor, cada centil representa 1% da população, com base nessa ordem.
#
# Com esses dados, é possível:
# - Detectar perfis econômicos regionais;
# - Comparar unidades federativas com características semelhantes;
# - Visualizar padrões geográficos da renda declarada;
# - Comunicar resultados de forma intuitiva a gestores e formuladores de políticas, orientando decisões baseadas em evidências.
#
# Assim, os dados da Receita Federal permitem transformar informações fiscais agregadas em insights sobre o perfil socioeconômico dos estados brasileiros, apoiando diagnósticos e ações voltadas à redução de desigualdades regionais.
#
# ### 1.4 Questões éticas envolvidas
#
# Embora a base seja pública e anonimizada, existem algumas questões éticas importantes a considerar:
# - **Privacidade dos contribuintes:** Os dados são agregados por centis e não permitem identificar indivíduos, o que mitiga riscos de exposição. Ainda assim, é fundamental respeitar os limites de granularidade e não tentar inferir características pessoais ou socioeconômicas individuais.
# - **Uso responsável das informações:** A interpretação incorreta dos dados (por exemplo, tirar conclusões causais indevidas) pode levar a distorções na comunicação pública. Deve-se deixar claro que os dados representam apenas pessoas físicas declarantes de IR, não toda a população brasileira.
# - **Viés de representatividade:** Como apenas uma parte da população brasileira declara imposto de renda (geralmente as faixas mais altas de renda), as conclusões não representam todo o espectro social.
#
# ---

# %% [markdown]
# ## 2. Identificação dos dados necessários
#
# ### 2.1 Dados internos
#
# Como este projeto utiliza dados públicos e não há acesso a bancos internos da Receita Federal, não há dados internos disponíveis para este estudo. Assim, este projeto se baseia exclusivamente em dados externos públicos e agregados.
#
# ### 2.2 Dados externos
#
# Segue a tabela em Markdown convertida a partir da lista:
#
# | Item | Detalhes |
# |---|---|
# | **Fonte principal** | Receita Federal do Brasil (RFB) |
# | **Nome do conjunto** | Distribuição de Renda |
# | **URL** | https://dados.gov.br/dados/conjuntos-dados/distribuio-de-renda |
# | **Descrição** | Esta base contém a distribuição da renda apurada pelos contribuintes em um determinado exercício, tendo por fonte as declarações de imposto de renda da pessoa física. As informações são agrupadas por centis e são apresentadas em nível nacional e por unidade da federação |
# | **Formato** | CSV (dados tabulares), PDF (dicionário de dados) |
# | **Licença** | Creative Commons Attribution |
# | **Última atualização** | Janeiro de 2023 |
# | **Responsável** | Receita Federal |
#
# > Esses dados são agregados e anonimizados, impossibilitando a identificação de indivíduos, o que garante segurança e privacidade.
#
# ---

# %% [markdown]
# ## 3. Arquitetura de Dados
#
# ### 3.1 Arquitetura dos dados
#
# A arquitetura de dados deste projeto foi planejada para ser simples, transparente e reprodutível, considerando o uso de dados públicos da Receita Federal do Brasil.
#
# | **Etapa** | **Descrição** |
# |---|---|
# | **Fontes de dados** |A principal fonte é o conjunto “Distribuição de Renda”, disponível no portal dados.gov.br, fornecido pela Receita Federal. Os dados estão no formato CSV (com dicionário em PDF) e apresentam informações agregadas sobre a renda declarada por contribuintes do imposto de renda, por centis e unidades da federação|
# | **Armazenamento** | Após o download, os arquivos foram armazenados localmente e posteriormente publicados em um repositório GitHub, juntamente com o notebook do projeto e o dicionário de dados. O uso do GitHub garante versionamento, reprodutibilidade e transparência |
# | **Distribuição e apresentação** | As análises, visualizações e resultados são realizados e apresentados diretamente no notebook em Python (Jupyter), que atua como a principal ferramenta de processamento e comunicação dos resultados |
#
# ```mermaid
# flowchart LR
#     A[Receita Federal - dados.gov.br - CSV/PDF] --> B[Download local - dados originais]
#     B --> C[Repositório GitHub - dados + notebook + dicionário]
#     C --> D[Notebook Jupyter - análise, visualização e resultados]
#     D --> E[Stakeholders / Leitores - professores, avaliadores, público]
# ```
#
# ![Figura 1: Arquitetura de Dados do Projeto](./data/fig1.png)
#
# ---

# %% [markdown]
# ## 4. Extrair e consolidar dados
#
# ### 4.1 Obter dados
#
# Realizar download da base disponível em https://dados.gov.br/dados/conjuntos-dados/distribuio-de-renda e anexar ao diretório de dados do projeto.
#
# ```sh
# /gb/
#     ├── data/
#     │    └── distribuicao-renda.csv
#     └── gb.ipynb
# ```
#
# ### 4.2 Leitura inicial dos dados

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/distribuicao-renda.csv', sep=';', decimal=",", thousands=".")

df.head()
df.info()
df.describe(include='all')

display(df.head())
print(df.columns.tolist())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46350 entries, 0 to 46349
# Data columns (total 24 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Ano-calendário                                                               46350 non-null  int64
#  1   Ente Federativo                                                              46350 non-null  object
#  2   Centil                                                                       46350 non-null  int64
#  3   Quantidade de Contribuintes                                                  46350 non-null  int64
#  4   Rendimentos Tributaveis - Limite Superior da RTB do Centil [R$ milhões]      42935 non-null  float64
#  5   Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]                 42935 non-null  float64
#  6   Rendimentos Tributaveis - RTB Acumulada do Centil [R$ milhões]               42935 non-null  float64
#  7   Rendimentos Tributaveis - Média da RTB do Centil [R$]                        42935 non-null  float64
#  8   Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]                        46219 non-null  float64
#  9   Rendimentos Isentos - Lucros e dividendos [R$ milhões]                       45891 non-null  float64
#  10  Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]  44459 non-null  float64
#  11  Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]                46276 non-null  float64
#  12  Despesas Dedutíveis - Previdência [R$ milhões]                               42921 non-null  float64
#  13  Despesas Dedutíveis - Dependentes [R$ milhões]                               42923 non-null  float64
#  14  Despesas Dedutíveis - Instrução [R$ milhões]                                 42735 non-null  float64
#  15  Despesas Dedutíveis - Médicas [R$ milhões]                                   42870 non-null  float64
#  16  Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]                        42446 non-null  float64
#  17  Despesas Dedutíveis - Livro-Caixa [R$ milhões]                               39593 non-null  float64
#  18  Imposto Devido [R$ milhões]                                                  38184 non-null  float64
#  19  Bens e Direitos - Imóveis [R$ milhões]                                       46305 non-null  float64
#  20  Bens e Direitos - Móveis [R$ milhões]                                        46278 non-null  float64
#  21  Bens e Direitos - Financeiros [R$ milhões]                                   46347 non-null  float64
#  22  Bens e Direitos - Outros Bens e Direitos [R$ milhões]                        46062 non-null  float64
#  23  Dívidas e Ônus [R$ milhões]                                                  46216 non-null  float64
# dtypes: float64(20), int64(3), object(1)
# memory usage: 8.5+ MB
#    Ano-calendário Ente Federativo  Centil  Quantidade de Contribuintes  \
# 0            2006          BRASIL       1                       241563
# 1            2006          BRASIL       2                       241563
# 2            2006          BRASIL       3                       241562
# 3            2006          BRASIL       4                       241563
# 4            2006          BRASIL       5                       241562
#
#    Rendimentos Tributaveis - Limite Superior da RTB do Centil [R$ milhões]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rendimentos Tributaveis - RTB Acumulada do Centil [R$ milhões]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rendimentos Tributaveis - Média da RTB do Centil [R$]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]  \
# 0                                             235.61
# 1                                             208.74
# 2                                             219.96
# 3                                             257.01
# 4                                             249.88
#
#    Rendimentos Isentos - Lucros e dividendos [R$ milhões]  ...  \
# 0                                             481.27       ...
# 1                                             483.44       ...
# 2                                             459.87       ...
# 3                                             481.93       ...
# 4                                             464.23       ...
#
#    Despesas Dedutíveis - Instrução [R$ milhões]  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Despesas Dedutíveis - Médicas [R$ milhões]  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Despesas Dedutíveis - Livro-Caixa [R$ milhões]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Imposto Devido [R$ milhões]  Bens e Direitos - Imóveis [R$ milhões]  \
# 0                         0.16                                 5281.59
# 1                         0.22                                 5295.48
# 2                         0.31                                 5566.27
# 3                         0.17                                 5860.02
# 4                         0.17                                 5193.31
#
#    Bens e Direitos - Móveis [R$ milhões]  \
# 0                                 686.21
# 1                                 668.82
# 2                                 670.64
# 3                                 678.44
# 4                                 682.38
#
#    Bens e Direitos - Financeiros [R$ milhões]  \
# 0                                     6549.15
# 1                                     5762.77
# 2                                     5451.95
# 3                                     6104.09
# 4                                     5592.52
#
#    Bens e Direitos - Outros Bens e Direitos [R$ milhões]  \
# 0                                            1006.40
# 1                                             681.75
# 2                                             377.17
# 3                                             256.16
# 4                                             269.28
#
#    Dívidas e Ônus [R$ milhões]
# 0                      1610.39
# 1                       694.12
# 2                       650.98
# 3                      1079.20
# 4                       671.97
#
# [5 rows x 24 columns]
# ['Ano-calendário', 'Ente Federativo', 'Centil', 'Quantidade de Contribuintes', 'Rendimentos Tributaveis - Limite Superior da RTB do Centil [R$ milhões]', 'Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]', 'Rendimentos Tributaveis - RTB Acumulada do Centil [R$ milhões]', 'Rendimentos Tributaveis - Média da RTB do Centil [R$]', 'Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]', 'Rendimentos Isentos - Lucros e dividendos [R$ milhões]', 'Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]', 'Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]', 'Despesas Dedutíveis - Previdência [R$ milhões]', 'Despesas Dedutíveis - Dependentes [R$ milhões]', 'Despesas Dedutíveis - Instrução [R$ milhões]', 'Despesas Dedutíveis - Médicas [R$ milhões]', 'Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]', 'Despesas Dedutíveis - Livro-Caixa [R$ milhões]', 'Imposto Devido [R$ milhões]', 'Bens e Direitos - Imóveis [R$ milhões]', 'Bens e Direitos - Móveis [R$ milhões]', 'Bens e Direitos - Financeiros [R$ milhões]', 'Bens e Direitos - Outros Bens e Direitos [R$ milhões]', 'Dívidas e Ônus [R$ milhões]']
# Ano-calendário                                                                   int64
# Ente Federativo                                                                 object
# Centil                                                                           int64
# Quantidade de Contribuintes                                                      int64
# Rendimentos Tributaveis - Limite Superior da RTB do Centil [R$ milhões]        float64
# Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]                   float64
# Rendimentos Tributaveis - RTB Acumulada do Centil [R$ milhões]                 float64
# Rendimentos Tributaveis - Média da RTB do Centil [R$]                          float64
# Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]                          float64
# Rendimentos Isentos - Lucros e dividendos [R$ milhões]                         float64
# Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]    float64
# Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]                  float64
# Despesas Dedutíveis - Previdência [R$ milhões]                                 float64
# Despesas Dedutíveis - Dependentes [R$ milhões]                                 float64
# Despesas Dedutíveis - Instrução [R$ milhões]                                   float64
# Despesas Dedutíveis - Médicas [R$ milhões]                                     float64
# Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]                          float64
# Despesas Dedutíveis - Livro-Caixa [R$ milhões]                                 float64
# Imposto Devido [R$ milhões]                                                    float64
# Bens e Direitos - Imóveis [R$ milhões]                                         float64
# Bens e Direitos - Móveis [R$ milhões]                                          float64
# Bens e Direitos - Financeiros [R$ milhões]                                     float64
# Bens e Direitos - Outros Bens e Direitos [R$ milhões]                          float64
# Dívidas e Ônus [R$ milhões]                                                    float64
# dtype: object

# %% [markdown]
# ### 4.3 Limpeza e preparação dos dados
#
# Removemos todas as linhas em que o Ente Federativo era "BRASIL", para focar apenas nas unidades da federação.

# %%
indices_to_drop = df[df['Ente Federativo'] == "BRASIL"].index
df = df.drop(indices_to_drop)

# %% [markdown]
# ### 4.4 Dados faltantes

# %%
df.isna().sum()
# Out:
# Ano-calendário                                                                    0
# Ente Federativo                                                                   0
# Centil                                                                            0
# Quantidade de Contribuintes                                                       0
# Rendimentos Tributaveis - Limite Superior da RTB do Centil [R$ milhões]        3300
# Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]                   3300
# Rendimentos Tributaveis - RTB Acumulada do Centil [R$ milhões]                 3300
# Rendimentos Tributaveis - Média da RTB do Centil [R$]                          3300
# Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]                           131
# Rendimentos Isentos - Lucros e dividendos [R$ milhões]                          459
# Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]    1891
# Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]                    74
# Despesas Dedutíveis - Previdência [R$ milhões]                                 3314
# Despesas Dedutíveis - Dependentes [R$ milhões]                                 3312
# Despesas Dedutíveis - Instrução [R$ milhões]                                   3500
# Despesas Dedutíveis - Médicas [R$ milhões]                                     3365
# Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]                          3789
# Despesas Dedutíveis - Livro-Caixa [R$ milhões]                                 6641
# Imposto Devido [R$ milhões]                                                    8097
# Bens e Direitos - Imóveis [R$ milhões]                                           45
# Bens e Direitos - Móveis [R$ milhões]                                            72
# Bens e Direitos - Financeiros [R$ milhões]                                        3
# Bens e Direitos - Outros Bens e Direitos [R$ milhões]                           288
# Dívidas e Ônus [R$ milhões]                                                     134
# dtype: int64

# %% [markdown]
# Podemos verificar a presença de dados faltantes (valores nulos) em diversas colunas. Porém, por se tratar de dados individuais e opcionais, isto é, alguns contribuintes podem não declarar certas informações ou não possuir aquele "bem", a presença de valores nulos é esperada. Assim, a decisão sobre como lidar com esses dados faltantes deve considerar o contexto e o objetivo da análise.
#
# Neste caso vamos manter os dados como estão, sem realizar imputação ou remoção de linhas, para preservar a integridade dos dados originais.
#
# ---

# %% [markdown]
# ## 5. Realizar a modelagem
#
# Será realizada uma análise não supervisionada com clustering K-means para agrupar estados semelhantes em termos de distribuição de renda.
#
# Essa análise é útil para identificar padrões e segmentar regiões com características econômicas similares, o que pode auxiliar na formulação de políticas públicas direcionadas.

# %% [markdown]
# ### 5.1 Seleção das variáveis

# %%
cols = [
    'Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]',
    'Rendimentos Tributaveis - Média da RTB do Centil [R$]',
    'Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]',
    'Rendimentos Isentos - Lucros e dividendos [R$ milhões]',
    'Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]',
    'Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]',
    'Despesas Dedutíveis - Previdência [R$ milhões]',
    'Despesas Dedutíveis - Dependentes [R$ milhões]',
    'Despesas Dedutíveis - Instrução [R$ milhões]',
    'Despesas Dedutíveis - Médicas [R$ milhões]',
    'Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]',
    'Despesas Dedutíveis - Livro-Caixa [R$ milhões]',
    'Imposto Devido [R$ milhões]',
    'Bens e Direitos - Imóveis [R$ milhões]',
    'Bens e Direitos - Móveis [R$ milhões]',
    'Bens e Direitos - Financeiros [R$ milhões]',
    'Bens e Direitos - Outros Bens e Direitos [R$ milhões]',
    'Dívidas e Ônus [R$ milhões]'
]

df_grouped = df.groupby('Ente Federativo')[cols].mean()

df_grouped.head()
# Out:
#                  Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]  \
# Ente Federativo
# AC                                                       29.265730
# AL                                                      101.571883
# AM                                                      152.870353
# AP                                                       33.572643
# BA                                                      496.175683
#
#                  Rendimentos Tributaveis - Média da RTB do Centil [R$]  \
# Ente Federativo
# AC                                                    83619.515606
# AL                                                    88928.998621
# AM                                                    88743.985154
# AP                                                    90974.665671
# BA                                                    80933.689563
#
#                  Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]  \
# Ente Federativo
# AC                                                        2.076180
# AL                                                        8.700370
# AM                                                       13.226927
# AP                                                        2.417387
# BA                                                       50.841655
#
#                  Rendimentos Isentos - Lucros e dividendos [R$ milhões]  \
# Ente Federativo
# AC                                                        1.212582
# AL                                                        8.576988
# AM                                                       18.551370
# AP                                                        0.912415
# BA                                                       58.552958
#
#                  Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]  \
# Ente Federativo
# AC                                                        0.270929
# AL                                                        1.549827
# AM                                                        2.430700
# AP                                                        0.326854
# BA                                                       13.268491
#
#                  Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]  \
# Ente Federativo
# AC                                                        3.433600
# AL                                                       18.786339
# AM                                                       19.823552
# AP                                                        2.662661
# BA                                                       87.236552
#
#                  Despesas Dedutíveis - Previdência [R$ milhões]  \
# Ente Federativo
# AC                                                     1.669635
# AL                                                     5.458533
# AM                                                     8.400105
# AP                                                     2.211045
# BA                                                    29.245219
#
#                  Despesas Dedutíveis - Dependentes [R$ milhões]  \
# Ente Federativo
# AC                                                     0.820847
# AL                                                     2.370484
# AM                                                     5.131210
# AP                                                     1.300710
# BA                                                    12.925709
#
#                  Despesas Dedutíveis - Instrução [R$ milhões]  \
# Ente Federativo
# AC                                                   0.420425
# AL                                                   1.620921
# AM                                                   2.949345
# AP                                                   1.005359
# BA                                                   9.029294
#
#                  Despesas Dedutíveis - Médicas [R$ milhões]  \
# Ente Federativo
# AC                                                 1.077834
# AL                                                 4.716348
# AM                                                 5.554317
# AP                                                 1.929980
# BA                                                26.254788
#
#                  Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]  \
# Ente Federativo
# AC                                                        0.447029
# AL                                                        1.014613
# AM                                                        1.971739
# AP                                                        0.734872
# BA                                                        4.711849
#
#                  Despesas Dedutíveis - Livro-Caixa [R$ milhões]  \
# Ente Federativo
# AC                                                     0.228355
# AL                                                     1.346238
# AM                                                     2.403383
# AP                                                     0.243250
# BA                                                     3.293652
#
#                  Imposto Devido [R$ milhões]  \
# Ente Federativo
# AC                                  3.267621
# AL                                 12.086113
# AM                                 16.975887
# AP                                  3.590060
# BA                                 50.731152
#
#                  Bens e Direitos - Imóveis [R$ milhões]  \
# Ente Federativo
# AC                                            25.186067
# AL                                            96.101261
# AM                                           125.378861
# AP                                            12.677806
# BA                                           603.964018
#
#                  Bens e Direitos - Móveis [R$ milhões]  \
# Ente Federativo
# AC                                            4.815212
# AL                                           21.011812
# AM                                           21.593315
# AP                                            2.852177
# BA                                          115.148006
#
#                  Bens e Direitos - Financeiros [R$ milhões]  \
# Ente Federativo
# AC                                                14.458176
# AL                                               111.962752
# AM                                               182.350242
# AP                                                 7.904752
# BA                                               620.017036
#
#                  Bens e Direitos - Outros Bens e Direitos [R$ milhões]  \
# Ente Federativo
# AC                                                        1.340179
# AL                                                        6.472727
# AM                                                       13.897842
# AP                                                        0.441034
# BA                                                       46.268133
#
#                  Dívidas e Ônus [R$ milhões]
# Ente Federativo
# AC                                  4.350522
# AL                                 21.196545
# AM                                 27.192418
# AP                                  2.921751
# BA                                191.541648

# %% [markdown]
# ### 5.2 Padronização dos dados

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_grouped)

# %% [markdown]
# ### 5.3 Método do cotovelo

# %%
inertia = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(K, inertia, 'bo-')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inércia')
plt.title('Método do Cotovelo para Determinar o k Ótimo')
plt.show()

# %% [markdown]
# ### 5.4 Aplicação do K-means

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df_grouped['Cluster'] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ### 5.5 Análise dos resultados

# %%
df_clusters = df_grouped.reset_index()
cluster_members = df_clusters.groupby('Cluster')['Ente Federativo'].apply(list)

for c, members in cluster_members.items():
    print(f"Cluster {c} ({len(members)} estados):")
    print(', '.join(members))
    print()

plt.figure(figsize=(8, 5))
bars = plt.bar(cluster_count['Cluster'], cluster_count['Count'])
plt.title('Number of Samples per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.xticks(cluster_count['Cluster'])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom', ha='center')

plt.show()
# Out:
# Cluster 0 (1 estados):
# SP
#
# Cluster 1 (21 estados):
# AC, AL, AM, AP, BA, CE, ES, GO, MA, MS, MT, PA, PB, PE, PI, RN, RO, RR, SC, SE, TO
#
# Cluster 2 (5 estados):
# DF, MG, PR, RJ, RS

# %% [markdown]
# ### 5.6 Resposta ao problema
#
# #### 5.6.1 Dados gerais dos Entes Federativos

# %%
n = len(cols)

fig, axes = plt.subplots(n, 1, figsize=(12, 4*n))
axes = axes.flatten()

for i, feat in enumerate(cols):
    ax = axes[i]
    sns.barplot(x=df_grouped.index.astype(str), y=df_grouped[feat].values, ax=ax)
    ax.set_title(feat)
    ax.set_xlabel('Cluster')
    ax.set_ylabel(feat)
    
    for p in ax.patches:
        ax.annotate(f"{p.get_height():.1f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='bottom', fontsize=9, rotation=0)

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.6.2 Classificação por Cluster

# %%
cluster_profile = df_grouped.groupby('Cluster')[cols].mean()
print("Perfis médios por cluster (médias das variáveis selecionadas):")
display(cluster_profile)

centroids_std = pd.DataFrame(kmeans.cluster_centers_, columns=df_grouped.columns[:-1]) 
print("Centroides (dados padronizados):")
display(centroids_std.T.sort_values(by=0, ascending=False)) 
centroids = centroids_std.copy()

def assign_label(centroid):
    if centroid.filter(like='Média').max() > 0.8 and centroid.filter(like='Bens e Direitos').max() > 0.5:
        return 'Alta renda / Alto patrimônio'
    if centroid.filter(like='Média').max() < -0.8:
        return 'Baixa renda'
    if centroid.filter(like='Dívidas').max() > 0.8:
        return 'Endividamento elevado'
    if centroid.filter(like='Imposto Devido').max() > 0.8:
        return 'Alta carga tributária'
    return 'Perfil intermediário / misto'

labels = {}
print("Resumo qualitativo por cluster:\n")
for i in centroids.index:
    s = centroids.loc[i]
    top_pos = s.sort_values(ascending=False).head(3)
    top_neg = s.sort_values().head(3)
    label = assign_label(s)
    labels[i] = label
    print(f"Cluster {i} -> {label}")
    print("  Top + :", ', '.join([f"{f} ({v:.2f})" for f,v in top_pos.items()]))
    print("  Top - :", ', '.join([f"{f} ({v:.2f})" for f,v in top_neg.items()]))
    print()

df_grouped['Cluster_label'] = df_grouped['Cluster'].map(labels)
display(df_grouped[['Cluster','Cluster_label']])
# Out:
# Perfis médios por cluster (médias das variáveis selecionadas):
#          Rendimentos Tributaveis - Soma da RTB do Centil [R$ milhões]  \
# Cluster
# 0                                              4511.335564
# 1                                               189.448905
# 2                                              1018.085235
#
#          Rendimentos Tributaveis - Média da RTB do Centil [R$]  \
# Cluster
# 0                                            100960.893197
# 1                                             84876.288535
# 2                                             98365.605679
#
#          Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões]  \
# Cluster
# 0                                              1000.470873
# 1                                                19.821778
# 2                                               157.454488
#
#          Rendimentos Isentos - Lucros e dividendos [R$ milhões]  \
# Cluster
# 0                                               989.109727
# 1                                                22.326031
# 2                                               157.880371
#
#          Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões]  \
# Cluster
# 0                                               243.422770
# 1                                                 4.986265
# 2                                                36.724930
#
#          Rendimentos Isentos - Outros Rendimentos Isentos [R$ milhões]  \
# Cluster
# 0                                              1433.197358
# 1                                                39.280374
# 2                                               264.227712
#
#          Despesas Dedutíveis - Previdência [R$ milhões]  \
# Cluster
# 0                                            188.936842
# 1                                             10.050647
# 2                                             50.424281
#
#          Despesas Dedutíveis - Dependentes [R$ milhões]  \
# Cluster
# 0                                             87.125311
# 1                                              4.615216
# 2                                             18.311861
#
#          Despesas Dedutíveis - Instrução [R$ milhões]  \
# Cluster
# 0                                           50.823956
# 1                                            2.930079
# 2                                           11.966086
#
#          Despesas Dedutíveis - Médicas [R$ milhões]  \
# Cluster
# 0                                        181.237523
# 1                                          8.145724
# 2                                         40.278118
#
#          Despesas Dedutíveis - Pensão Alimentícia [R$ milhões]  \
# Cluster
# 0                                                34.413249
# 1                                                 1.902199
# 2                                                 9.573473
#
#          Despesas Dedutíveis - Livro-Caixa [R$ milhões]  \
# Cluster
# 0                                             62.844537
# 1                                              2.873788
# 2                                             16.255742
#
#          Imposto Devido [R$ milhões]  Bens e Direitos - Imóveis [R$ milhões]  \
# Cluster
# 0                         495.490932                             9386.201152
# 1                          20.342807                              255.609928
# 2                         115.825151                             1848.315798
#
#          Bens e Direitos - Móveis [R$ milhões]  \
# Cluster
# 0                                  1615.738764
# 1                                    56.485760
# 2                                   337.093127
#
#          Bens e Direitos - Financeiros [R$ milhões]  \
# Cluster
# 0                                      15081.357048
# 1                                        267.661430
# 2                                       2260.370695
#
#          Bens e Direitos - Outros Bens e Direitos [R$ milhões]  \
# Cluster
# 0                                               705.222709
# 1                                                24.318862
# 2                                               135.918030
#
#          Dívidas e Ônus [R$ milhões]
# Cluster
# 0                        1893.575370
# 1                          67.818778
# 2                         358.257709
# Centroides (dados padronizados):
#                                                            0         1  \
# Rendimentos Isentos - Rendim. Sócio/Titular ME/...  4.847815 -0.318709
# Bens e Direitos - Financeiros [R$ milhões]          4.811295 -0.317732
# Rendimentos Isentos - Lucros e dividendos [R$ m...  4.803708 -0.322993
# Rendimentos Sujeitos à Tribut. Exclusiva [R$ mi...  4.792150 -0.322355
# Rendimentos Isentos - Outros Rendimentos Isento...  4.732374 -0.339413
# Dívidas e Ônus [R$ milhões]                         4.711254 -0.335596
# Bens e Direitos - Imóveis [R$ milhões]              4.704729 -0.350532
# Despesas Dedutíveis - Dependentes [R$ milhões]      4.654281 -0.338392
# Bens e Direitos - Outros Bens e Direitos [R$ mi...  4.649166 -0.335939
# Bens e Direitos - Móveis [R$ milhões]               4.648822 -0.351866
# Rendimentos Tributaveis - Soma da RTB do Centil...  4.585862 -0.358691
# Despesas Dedutíveis - Médicas [R$ milhões]          4.552098 -0.350087
# Despesas Dedutíveis - Instrução [R$ milhões]        4.545914 -0.352570
# Imposto Devido [R$ milhões]                         4.542542 -0.364338
# Despesas Dedutíveis - Previdência [R$ milhões]      4.420599 -0.378309
# Despesas Dedutíveis - Livro-Caixa [R$ milhões]      4.401609 -0.374233
# Despesas Dedutíveis - Pensão Alimentícia [R$ mi...  4.341664 -0.381300
# Rendimentos Tributaveis - Média da RTB do Centi...  1.225189 -0.291777
#
#                                                            2
# Rendimentos Isentos - Rendim. Sócio/Titular ME/...  0.369015
# Bens e Direitos - Financeiros [R$ milhões]          0.372215
# Rendimentos Isentos - Lucros e dividendos [R$ m...  0.395830
# Rendimentos Sujeitos à Tribut. Exclusiva [R$ mi...  0.395459
# Rendimentos Isentos - Outros Rendimentos Isento...  0.479061
# Dívidas e Ônus [R$ milhões]                         0.467251
# Bens e Direitos - Imóveis [R$ milhões]              0.531289
# Despesas Dedutíveis - Dependentes [R$ milhões]      0.490390
# Bens e Direitos - Outros Bens e Direitos [R$ mi...  0.481112
# Bens e Direitos - Móveis [R$ milhões]               0.548072
# Rendimentos Tributaveis - Soma da RTB do Centil...  0.589329
# Despesas Dedutíveis - Médicas [R$ milhões]          0.559944
# Despesas Dedutíveis - Instrução [R$ milhões]        0.571613
# Imposto Devido [R$ milhões]                         0.621713
# Despesas Dedutíveis - Previdência [R$ milhões]      0.704778
# Despesas Dedutíveis - Livro-Caixa [R$ milhões]      0.691455
# Despesas Dedutíveis - Pensão Alimentícia [R$ mi...  0.733126
# Rendimentos Tributaveis - Média da RTB do Centi...  0.980424
# Resumo qualitativo por cluster:
#
# Cluster 0 -> Alta renda / Alto patrimônio
#   Top + : Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões] (4.85), Bens e Direitos - Financeiros [R$ milhões] (4.81), Rendimentos Isentos - Lucros e dividendos [R$ milhões] (4.80)
#   Top - : Rendimentos Tributaveis - Média da RTB do Centil [R$] (1.23), Despesas Dedutíveis - Pensão Alimentícia [R$ milhões] (4.34), Despesas Dedutíveis - Livro-Caixa [R$ milhões] (4.40)
#
# Cluster 1 -> Perfil intermediário / misto
#   Top + : Rendimentos Tributaveis - Média da RTB do Centil [R$] (-0.29), Bens e Direitos - Financeiros [R$ milhões] (-0.32), Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões] (-0.32)
#   Top - : Despesas Dedutíveis - Pensão Alimentícia [R$ milhões] (-0.38), Despesas Dedutíveis - Previdência [R$ milhões] (-0.38), Despesas Dedutíveis - Livro-Caixa [R$ milhões] (-0.37)
#
# Cluster 2 -> Alta renda / Alto patrimônio
#   Top + : Rendimentos Tributaveis - Média da RTB do Centil [R$] (0.98), Despesas Dedutíveis - Pensão Alimentícia [R$ milhões] (0.73), Despesas Dedutíveis - Previdência [R$ milhões] (0.70)
#   Top - : Rendimentos Isentos - Rendim. Sócio/Titular ME/EPP Opt SIMPLES [R$ milhões] (0.37), Bens e Direitos - Financeiros [R$ milhões] (0.37), Rendimentos Sujeitos à Tribut. Exclusiva [R$ milhões] (0.40)
#                  Cluster                 Cluster_label
# Ente Federativo
# AC                     1  Perfil intermediário / misto
# AL                     1  Perfil intermediário / misto
# AM                     1  Perfil intermediário / misto
# AP                     1  Perfil intermediário / misto
# BA                     1  Perfil intermediário / misto
# CE                     1  Perfil intermediário / misto
# DF                     2  Alta renda / Alto patrimônio
# ES                     1  Perfil intermediário / misto
# GO                     1  Perfil intermediário / misto
# MA                     1  Perfil intermediário / misto
# MG                     2  Alta renda / Alto patrimônio
# MS                     1  Perfil intermediário / misto
# MT                     1  Perfil intermediário / misto
# PA                     1  Perfil intermediário / misto
# PB                     1  Perfil intermediário / misto
# PE                     1  Perfil intermediário / misto
# PI                     1  Perfil intermediário / misto
# PR                     2  Alta renda / Alto patrimônio
# RJ                     2  Alta renda / Alto patrimônio
# RN                     1  Perfil intermediário / misto
# RO                     1  Perfil intermediário / misto
# RR                     1  Perfil intermediário / misto
# RS                     2  Alta renda / Alto patrimônio
# SC                     1  Perfil intermediário / misto
# SE                     1  Perfil intermediário / misto
# SP                     0  Alta renda / Alto patrimônio
# TO                     1  Perfil intermediário / misto

# %% [markdown]
# ## 6. Projetando a Implantação da solução
#
# - Como essa análise melhora a tomada de decisão?
#     - Gera evidência segmentada: transforma muitas métricas em perfis de estados (clusters) que são fáceis de comparar.
#     - Permite priorizar ações e alocar recursos onde há maior impacto (ex.: fiscalização em clusters de alto patrimônio).
#     - Facilita monitoramento e comunicação com gestores por meio de gráficos e KPIs por cluster.
#
# - O que muda no processo de tomada de decisão?
#     - Passa de ações uniformes para ações direcionadas por cluster.
#     - Introduz ciclos regulares de monitoramento (avaliar → agir → reavaliar).
#     - Reduz decisões baseadas em média nacional, diminuindo risco de intervenções ineficazes.
#
# - Como essa análise ou indicador será inserido no processo atual?
#     - Pipeline: atualizar CSV → pré-processar (filtrar UFs, padronizar) → rodar clustering → publicar resumo/visualização.
#     - Entregar via dashboard (Power BI) e relatório periódico (ex.: anual/semestre).
#     - Documentar metodologia e definir responsáveis e cadência de atualização.
#
# - Quem serão as pessoas que vão consumir esses dados? Será necessário treinar funcionários?
#     - Consumidores: analistas de dados, equipes de fiscalização/auditoria, gestores de políticas, secretarias estaduais e pesquisadores.
#     - Treinamento: sim — breve formação para gestores (interpretação, uso do dashboard) e formação técnica para analistas (reprodutibilidade do pipeline e interpretação dos centroides). Material: guia rápido + notebook reproducível + workshop curto.

# %% [markdown]
# ## 7. Conclusão
#
# São Paulo (SP) se destaca claramente como a unidade federativa com maior renda declarada, seguida por Distrito Federal (DF), Minas Gerais (MG), Paraná (PR), Rio de Janeiro (RJ) e Rio Grande do Sul (RS); esses estados compõem o grupo de maior capacidade contributiva e patrimônio médio por centil. Em contraste, o conjunto remanescente (AC, AL, AM, AP, BA, CE, ES, GO, MA, MS, MT, PA, PB, PE, PI, RN, RO, RR, SC, SE, TO) apresenta níveis de renda muito inferiores, indicando desigualdade regional marcada e a necessidade de políticas e prioridades diferenciadas por cluster para reduzir disparidades e otimizar alocação de recursos.
